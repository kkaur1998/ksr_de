# %%
import pandas as pd

# %%
data = pd.read_excel("data/superstore.xlsx")

# %%
df = data.copy()

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2698  CA-2016-145317 2016-03-18 2016-03-23  Standard Class    SM-20320
# 1    6827  CA-2018-118689 2018-10-02 2018-10-09  Standard Class    TC-20980
#
#   Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0   Sean Miller  Home Office  United States  Jacksonville  ...     32216.0
# 1  Tamara Chand    Corporate  United States     Lafayette  ...     47905.0
#
#     Region       Product ID    Category Sub-Category  \
# 0    South  TEC-MA-10002412  Technology     Machines
# 1  Central  TEC-CO-10004722  Technology      Copiers
#
#                                         Product Name     Sales  Quantity  \
# 0  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
# 1              Canon imageCLASS 2200 Advanced Copier  17499.95         5
#
#    Discount     Profit
# 0       0.5 -1811.0784
# 1       0.0  8399.9760
#
# [2 rows x 21 columns]

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df1 = df[[ 'Segment',  'Region',  'Category','Sub-Category', 'Sales', 'Quantity','Profit']]

# %%
df1.head(2)
# Out:
#        Segment   Region    Category Sub-Category     Sales  Quantity  \
# 0  Home Office    South  Technology     Machines  22638.48         6
# 1    Corporate  Central  Technology      Copiers  17499.95         5
#
#       Profit
# 0 -1811.0784
# 1  8399.9760

# %%
df1.iloc[0:3,:]
# Out:
#        Segment   Region    Category Sub-Category     Sales  Quantity  \
# 0  Home Office    South  Technology     Machines  22638.48         6
# 1    Corporate  Central  Technology      Copiers  17499.95         5
# 2     Consumer     West  Technology      Copiers  13999.96         4
#
#       Profit
# 0 -1811.0784
# 1  8399.9760
# 2  6719.9808

# %%
df1.columns
# Out:
# Index(['Segment', 'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity',
#        'Profit'],
#       dtype='object')

# %%
df1.groupby('Region').sum('Sales')
# Out:
#                Sales  Quantity       Profit
# Region
# Central  501239.8908      8780   39706.3625
# East     678781.2400     10618   91522.7800
# South    391721.9050      6209   46749.4303
# West     725457.8245     12266  108418.4489

# %%
df1[['Region','Category','Sales','Quantity','Profit']].groupby(['Region','Category']).sum()
# Out:
#                                Sales  Quantity      Profit
# Region  Category
# Central Furniture        163797.1638      1827  -2871.0494
#         Office Supplies  167026.4150      5409   8879.9799
#         Technology       170416.3120      1544  33697.4320
# East    Furniture        208291.2040      2214   3046.1658
#         Office Supplies  205516.0550      6462  41014.5791
#         Technology       264973.9810      1942  47462.0351
# South   Furniture        117298.6840      1291   6771.2061
#         Office Supplies  125651.3130      3800  19986.3928
#         Technology       148771.9080      1118  19991.8314
# West    Furniture        252612.7435      2696  11504.9503
#         Office Supplies  220853.2490      7235  52609.8490
#         Technology       251991.8320      2335  44303.6496

# %%
df2 = df1.groupby(['Region','Category'])[['Sales','Quantity','Profit']].sum()
df2.loc['Central']
# Out:
#                        Sales  Quantity      Profit
# Category
# Furniture        163797.1638      1827  -2871.0494
# Office Supplies  167026.4150      5409   8879.9799
# Technology       170416.3120      1544  33697.4320

# %%
df2.reset_index()
# Out:
#      Region         Category        Sales  Quantity      Profit
# 0   Central        Furniture  163797.1638      1827  -2871.0494
# 1   Central  Office Supplies  167026.4150      5409   8879.9799
# 2   Central       Technology  170416.3120      1544  33697.4320
# 3      East        Furniture  208291.2040      2214   3046.1658
# 4      East  Office Supplies  205516.0550      6462  41014.5791
# 5      East       Technology  264973.9810      1942  47462.0351
# 6     South        Furniture  117298.6840      1291   6771.2061
# 7     South  Office Supplies  125651.3130      3800  19986.3928
# 8     South       Technology  148771.9080      1118  19991.8314
# 9      West        Furniture  252612.7435      2696  11504.9503
# 10     West  Office Supplies  220853.2490      7235  52609.8490
# 11     West       Technology  251991.8320      2335  44303.6496

# %%
df3 = df1.groupby('Segment').agg({"Sales":['sum','mean'],"Profit":'mean'}).rename(columns={'sum':'total_sales','mean':'avg_sales'})

# %%
df3.head()
# Out:
#                     Sales                 Profit
#               total_sales   avg_sales  avg_sales
# Segment
# Consumer     1.161401e+06  223.733644  25.836873
# Corporate    7.061464e+05  233.823300  30.456667
# Home Office  4.296531e+05  240.972041  33.818664

# %%
df3.rename(columns={"( 'Sales', 'total_sales')":'total_sales',"( 'Sales', 'avg_sales')":'avg_sales', "( 'Profit', 'avg_sales')":'avg_profit'})
# Out:
#                     Sales                 Profit
#               total_sales   avg_sales  avg_sales
# Segment
# Consumer     1.161401e+06  223.733644  25.836873
# Corporate    7.061464e+05  233.823300  30.456667
# Home Office  4.296531e+05  240.972041  33.818664
