# %% [markdown]
# # BAsic

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/car data.csv")
data.head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
df=data.copy()

# %%
#first two rows of dataframe
df.head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
#last two rows of dataframe
df.tail(2)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 299     city  2017           11.5           12.5        9000    Diesel
# 300     brio  2016            5.3            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
#size of data
size = df.shape
print(" size of data in rows and columns having size: ",size,"\n no. of rows df:",size[0], "\n no. of columns in df:", size[1])
# Out:
#  size of data in rows and columns having size:  (301, 9)
#  no. of rows df: 301
#  no. of columns in df: 9

# %%
#converting all the column names to lowercase
columns = df.columns
renamed_columns = {i:i.lower() for i in columns}

# %%
#renaming columns 
df.rename(columns=renamed_columns,inplace=True)
df.head()
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.describe()
# Out:
#               year  selling_price  present_price     kms_driven       owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
pd.DataFrame(df['car_name'].value_counts().reset_index()).head(5)
# Out:
#         car_name  count
# 0           city     26
# 1  corolla altis     16
# 2          verna     14
# 3       fortuner     11
# 4           brio     10

# %%
df[df['year']==2014].head(2)
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df[(df['year']==2014) & (df['transmission']=='Manual') & (df['fuel_type']=='Petrol')].head(2)
# Out:
#     car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 23  alto k10  2014           2.50           3.46       45280    Petrol
#
#    seller_type transmission  owner
# 0       Dealer       Manual      0
# 23      Dealer       Manual      0

# %%
df[(df['year']==2014) & (df['kms_driven']<=15000)  & (df['transmission']=='Automatic')].head(2)
# Out:
#    car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 45     ciaz  2014            7.5          12.04       15000    Petrol
#
#    seller_type transmission  owner
# 45      Dealer    Automatic      0

# %%
df[df['year'].isin([2014,2015,2016])].count()
# Out:
# car_name         149
# year             149
# selling_price    149
# present_price    149
# kms_driven       149
# fuel_type        149
# seller_type      149
# transmission     149
# owner            149
# dtype: int64

# %%
df[df['year'].isin([2014,2015,2016])][['car_name','year','selling_price']]
# Out:
#     car_name  year  selling_price
# 0       ritz  2014           3.35
# 4      swift  2014           4.60
# 6       ciaz  2015           6.75
# 7    s cross  2015           6.50
# 8       ciaz  2016           8.75
# ..       ...   ...            ...
# 294    amaze  2014           3.75
# 295     city  2015           8.55
# 296     city  2016           9.50
# 297     brio  2015           4.00
# 300     brio  2016           5.30
#
# [149 rows x 3 columns]

# %%
df.transmission.str.replace('m','M')
# Out:
# 0      Manual
# 1      Manual
# 2      Manual
# 3      Manual
# 4      Manual
#         ...
# 296    Manual
# 297    Manual
# 298    Manual
# 299    Manual
# 300    Manual
# Name: transmission, Length: 301, dtype: object

# %%
df[(df['year']==2014) & (df['kms_driven']<=15000)].head(2)
# Out:
#           car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 45            ciaz  2014           7.50          12.04       15000    Petrol
# 112  KTM 390 Duke   2014           1.15           2.40        7000    Petrol
#
#     seller_type transmission  owner
# 45       Dealer    Automatic      0
# 112  Individual       Manual      0

# %%
df.sort_values(['year','transmission','selling_price'])
# Out:
#                 car_name  year  selling_price  present_price  kms_driven  \
# 37                   800  2003           0.35           2.28      127000
# 39                   sx4  2003           2.25           7.98       62000
# 77               corolla  2004           1.50          12.35      135154
# 189  Hero Super Splendor  2005           0.20           0.57       55000
# 54                innova  2005           2.75          10.21       90000
# ..                   ...   ...            ...            ...         ...
# 235                verna  2017           9.10           9.40       15141
# 231                verna  2017           9.25           9.40       15001
# 299                 city  2017          11.50          12.50        9000
# 97         corolla altis  2017          17.00          18.64        8700
# 5          vitara brezza  2018           9.25           9.83        2071
#
#     fuel_type seller_type transmission  owner
# ...

# %% [markdown]
# # Different ways of filtering

# %%
#petrol cars with all columns
df.head(2)
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
df[['car_name','fuel_type','year']][df['fuel_type']=='Petrol'].head(2)
# Out:
#   car_name fuel_type  year
# 0     ritz    Petrol  2014
# 2     ciaz    Petrol  2017

# %%
df.query('fuel_type=="Petrol"').head(2)
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
df.iloc[np.where(df['fuel_type']=='Petrol')].head(2)
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
data.loc[df['fuel_type']=='Petrol'].head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
df['fuel_type']=='Petrol'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 296    False
# 297     True
# 298     True
# 299    False
# 300     True
# Name: fuel_type, Length: 301, dtype: bool

# %%
data.iloc[df['fuel_type']=='Petrol'].head(2)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 data.iloc[df['fuel_type']=='Petrol'].head(2)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1700, in _iLocIndexer._getitem_axis(self, key, axis)
#    1697     key = np.asarray(key)
#    1699 if com.is_bool_indexer(key):
# -> 1700     self._validate_key(key, axis)
#    1701     return self._getbool_axis(key, axis=axis)
#    1703 # a list of integers
#
# File D:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1540, in _iLocIndexer._validate_key(self, key, axis)
# ...

# %%
df.sort_values('selling_price').iloc[0:9,]
# Out:
#                car_name  year  selling_price  present_price  kms_driven  \
# 200    Bajaj Pulsar 150  2006           0.10          0.750       92233
# 199      Honda CB Shine  2007           0.12          0.580       53000
# 198  Bajaj Discover 125  2011           0.15          0.570       35000
# 197    Honda CB twister  2010           0.16          0.510       33000
# 196           Activa 3g  2008           0.17          0.520      500000
# 195       Bajaj  ct 100  2015           0.18          0.320       35000
# 190    Bajaj Pulsar 150  2008           0.20          0.750       60000
# 191  Bajaj Discover 125  2012           0.20          0.570       25000
# 194    Hero  CBZ Xtreme  2008           0.20          0.787       50000
#
#     fuel_type seller_type transmission  owner
# 200    Petrol  Individual       Manual      0
# 199    Petrol  Individual       Manual      0
# 198    Petrol  Individual       Manual      1
# 197    Petrol  Individual       Manual      0
# ...

# %%
df.sort_values(by = {'selling_price':'desc','kms_driven':'asc'}).iloc[0:9]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5020\2591131736.py in ?()
# ----> 1 df.sort_values(by = {'selling_price':'desc','kms_driven':'asc'}).iloc[0:9]
#
# D:\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# D:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
# ...

# %%
[i**2 for i in range(20) if i**2<100]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
2**4
# Out:
# 16
